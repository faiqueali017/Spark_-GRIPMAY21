# %% [markdown]
# # Name : Muhammad Haris Uddin Siddiqui
# # The Spark Foundation
# ### Task 3 ‘Exploratory Data Analysis’ on dataset ‘SampleSuperstore’

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
d_set = pd.read_csv("SampleSuperstore.csv")
d_set.head(2)
# Out:
#       Ship Mode   Segment        Country       City     State  Postal Code  \
# 0  Second Class  Consumer  United States  Henderson  Kentucky        42420
# 1  Second Class  Consumer  United States  Henderson  Kentucky        42420
#
#   Region   Category Sub-Category   Sales  Quantity  Discount    Profit
# 0  South  Furniture    Bookcases  261.96         2       0.0   41.9136
# 1  South  Furniture       Chairs  731.94         3       0.0  219.5820

# %%
d_set["Sales"].sum()
# Out:
# 2297200.8603

# %%
d_set.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
d_set.shape
# Out:
# (9994, 13)

# %%
d_set.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
d_set[d_set.duplicated(keep = False)]
# Out:
#            Ship Mode      Segment        Country           City         State  \
# 568   Standard Class    Corporate  United States        Seattle    Washington
# 591   Standard Class     Consumer  United States          Salem        Oregon
# 935   Standard Class  Home Office  United States   Philadelphia  Pennsylvania
# 950   Standard Class  Home Office  United States   Philadelphia  Pennsylvania
# 1186  Standard Class    Corporate  United States        Seattle    Washington
# 1479  Standard Class     Consumer  United States  San Francisco    California
# 2803  Standard Class     Consumer  United States  San Francisco    California
# 2807    Second Class     Consumer  United States        Seattle    Washington
# 2836  Standard Class     Consumer  United States    Los Angeles    California
# 3127  Standard Class     Consumer  United States  New York City      New York
# 3405  Standard Class  Home Office  United States       Columbus          Ohio
# ...

# %%
d_set.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
d_set.drop_duplicates(subset = None , keep='first',inplace = True )

# %%
d_set
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
d_set.duplicated().sum()
# Out:
# 0

# %%
d_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9977 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9977 non-null   object
#  1   Segment       9977 non-null   object
#  2   Country       9977 non-null   object
#  3   City          9977 non-null   object
#  4   State         9977 non-null   object
#  5   Postal Code   9977 non-null   int64
#  6   Region        9977 non-null   object
#  7   Category      9977 non-null   object
#  8   Sub-Category  9977 non-null   object
#  9   Sales         9977 non-null   float64
#  10  Quantity      9977 non-null   int64
#  11  Discount      9977 non-null   float64
#  12  Profit        9977 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1.1+ MB

# %%
sns.pairplot(d_set,height = 3);

# %%
plt.pie(d_set["Ship Mode"].value_counts(), labels = d_set["Ship Mode"].value_counts().index, startangle = 90,autopct ='% 1.1f %%')
plt.title("Ship Mode")
# Out:
# Text(0.5, 1.0, 'Ship Mode')

# %%
d_set.head(1)
# Out:
#       Ship Mode   Segment        Country       City     State  Postal Code  \
# 0  Second Class  Consumer  United States  Henderson  Kentucky        42420
#
#   Region   Category Sub-Category   Sales  Quantity  Discount   Profit
# 0  South  Furniture    Bookcases  261.96         2       0.0  41.9136

# %%
d_set["Region"].head(2)
# Out:
# 0    South
# 1    South
# Name: Region, dtype: object

# %%
plt.pie(d_set["Region"].value_counts() , labels = d_set["Region"].value_counts().index , startangle = 90 , autopct = '% 1.1f &&')
plt.title("Region")
# Out:
# Text(0.5, 1.0, 'Region')

# %%
plt.pie(d_set["Category"].value_counts() , labels = d_set["Category"].value_counts().index ,startangle = 90, autopct = '% 1.1f %%' )
plt.title("Category")
# Out:
# Text(0.5, 1.0, 'Category')

# %%
sns.countplot(x = d_set["Sub-Category"])
plt.title("Sub-Category")
plt.xticks(rotation = 80)
plt.show()

# %%
plt.figure(figsize=(18,10))
sns.countplot(x = d_set["State"])
plt.title("State")
plt.xticks(rotation = 90)
plt.show()

# %%
d_set["City"].value_counts()
# Out:
# New York City    914
# Los Angeles      746
# Philadelphia     536
# San Francisco    506
# Seattle          424
#                 ...
# Orland Park        1
# Glenview           1
# Baytown            1
# Whittier           1
# Antioch            1
# Name: City, Length: 531, dtype: int64

# %%
d_set['freq'] = d_set.groupby("City")["City"].transform("count")

# %% [markdown]
# #

# %%
df1 = d_set.sort_values("freq" , ascending = False ).groupby("City").head(10)

# %%
df1
# Out:
#            Ship Mode      Segment        Country           City         State  \
# 3322  Standard Class  Home Office  United States  New York City      New York
# 2295  Standard Class     Consumer  United States  New York City      New York
# 2153  Standard Class    Corporate  United States  New York City      New York
# 2149  Standard Class     Consumer  United States  New York City      New York
# 6127  Standard Class     Consumer  United States  New York City      New York
# ...              ...          ...            ...            ...           ...
# 3402     First Class    Corporate  United States    Tinley Park      Illinois
# 9260    Second Class     Consumer  United States       Aberdeen  South Dakota
# 4878     First Class     Consumer  United States      Pensacola       Florida
# 205   Standard Class     Consumer  United States       Whittier    California
# 1895  Standard Class     Consumer  United States       Missoula       Montana
#
# ...

# %%
df1 = df1[["City" , "freq"]]

# %%
df1
# Out:
#                City  freq
# 3322  New York City   914
# 2295  New York City   914
# 2153  New York City   914
# 2149  New York City   914
# 6127  New York City   914
# ...             ...   ...
# 3402    Tinley Park     1
# 9260       Aberdeen     1
# 4878      Pensacola     1
# 205        Whittier     1
# 1895       Missoula     1
#
# [3096 rows x 2 columns]

# %%
df1.drop_duplicates(subset = None , keep = "first", inplace = True)
# Out:
# <ipython-input-27-e7268b6367cf>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop_duplicates(subset = None , keep = "first", inplace = True)

# %%
df1
# Out:
#                City  freq
# 3322  New York City   914
# 9234    Los Angeles   746
# 4404   Philadelphia   536
# 5820  San Francisco   506
# 4895        Seattle   424
# ...             ...   ...
# 3402    Tinley Park     1
# 9260       Aberdeen     1
# 4878      Pensacola     1
# 205        Whittier     1
# 1895       Missoula     1
#
# [531 rows x 2 columns]

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1 = df1.head(10)

# %%
df1
# Out:
#                City  freq
# 3322  New York City   914
# 9234    Los Angeles   746
# 4404   Philadelphia   536
# 5820  San Francisco   506
# 4895        Seattle   424
# 9541        Houston   375
# 5567        Chicago   313
# 8847       Columbus   221
# 7828      San Diego   170
# 542     Springfield   163

# %%
plt.figure(figsize = [14.70, 8.27])
plt.subplots_adjust(wspace = 0.85)
sns.barplot(x = df1['City'], y = d_set['freq'], color = sns.color_palette()[9]);
plt.xticks(rotation = 90)
plt.show()

# %%
d_set.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'freq'],
#       dtype='object')

# %%
n_set = ['Sales' , 'Discount' , 'Profit' , 'Quantity']

# %%
plt.figure(figsize=(10,8))
sns.heatmap(d_set[n_set].corr(),annot = True, fmt='.4f',center=0)
# Out:
# <AxesSubplot:>
